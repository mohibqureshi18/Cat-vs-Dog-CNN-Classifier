# %%
import pandas as pd
import numpy as np

df = pd.read_csv("churn.csv")

df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# StreamingTV                     No            No              No
# StreamingMovies                 No            No              No
# Contract            Month-to-month      One year  Month-to-month
# PaperlessBilling               Yes            No             Yes
# PaymentMethod     Electronic check  Mailed check    Mailed check
# MonthlyCharges               29.85         56.95           53.85
# TotalCharges                 29.85        1889.5          108.15
# Churn                           No            No             Yes
#
#                                           3                 4
# customerID                       7795-CFOCW        9237-HQITU
# gender                                 Male            Female
# SeniorCitizen                             0                 0
# Partner                                  No                No
# Dependents                               No                No
# tenure                                   45                 2
# PhoneService                             No               Yes
# MultipleLines              No phone service                No
# InternetService                         DSL       Fiber optic
# OnlineSecurity                          Yes                No
# OnlineBackup                             No                No
# DeviceProtection                        Yes                No
# TechSupport                             Yes                No
# StreamingTV                              No                No
# StreamingMovies                          No                No
# Contract                           One year    Month-to-month
# PaperlessBilling                         No               Yes
# PaymentMethod     Bank transfer (automatic)  Electronic check
# MonthlyCharges                         42.3              70.7
# TotalCharges                        1840.75            151.65
# Churn                                    No               Yes

# %%
df.tail().T
# Out:
#                           7038                     7039              7040  \
# customerID          6840-RESVB               2234-XADUH        4801-JZAZL
# gender                    Male                   Female            Female
# SeniorCitizen                0                        0                 0
# Partner                    Yes                      Yes               Yes
# Dependents                 Yes                      Yes               Yes
# tenure                      24                       72                11
# PhoneService               Yes                      Yes                No
# MultipleLines              Yes                      Yes  No phone service
# InternetService            DSL              Fiber optic               DSL
# OnlineSecurity             Yes                       No               Yes
# OnlineBackup                No                      Yes                No
# DeviceProtection           Yes                      Yes                No
# TechSupport                Yes                       No                No
# StreamingTV                Yes                      Yes                No
# StreamingMovies            Yes                      Yes                No
# Contract              One year                 One year    Month-to-month
# PaperlessBilling           Yes                      Yes               Yes
# PaymentMethod     Mailed check  Credit card (automatic)  Electronic check
# MonthlyCharges            84.8                    103.2              29.6
# TotalCharges            1990.5                   7362.9            346.45
# Churn                       No                       No                No
#
#                             7041                       7042
# customerID            8361-LTMKD                 3186-AJIEK
# gender                      Male                       Male
# SeniorCitizen                  1                          0
# Partner                      Yes                         No
# Dependents                    No                         No
# tenure                         4                         66
# PhoneService                 Yes                        Yes
# MultipleLines                Yes                         No
# InternetService      Fiber optic                Fiber optic
# OnlineSecurity                No                        Yes
# OnlineBackup                  No                         No
# DeviceProtection              No                        Yes
# TechSupport                   No                        Yes
# StreamingTV                   No                        Yes
# StreamingMovies               No                        Yes
# Contract          Month-to-month                   Two year
# PaperlessBilling             Yes                        Yes
# PaymentMethod       Mailed check  Bank transfer (automatic)
# MonthlyCharges              74.4                     105.65
# TotalCharges               306.6                     6844.5
# Churn                        Yes                         No

# %%
df.sample(10).T
# Out:
#                                      2972                     4584  \
# customerID                     9443-JUBUO               7524-VRLPL
# gender                               Male                     Male
# SeniorCitizen                           0                        1
# Partner                               Yes                       No
# Dependents                            Yes                       No
# tenure                                 72                       69
# PhoneService                           No                      Yes
# MultipleLines            No phone service                      Yes
# InternetService                       DSL                      DSL
# OnlineSecurity                        Yes                      Yes
# OnlineBackup                          Yes                       No
# DeviceProtection                      Yes                      Yes
# TechSupport                           Yes                      Yes
# StreamingTV                           Yes                       No
# StreamingMovies                       Yes                      Yes
# Contract                         Two year                 Two year
# PaperlessBilling                      Yes                       No
# PaymentMethod     Credit card (automatic)  Credit card (automatic)
# MonthlyCharges                      65.25                     74.1
# TotalCharges                      4478.85                   5031.0
# Churn                                  No                       No
#
#                             2543                     4715  \
# customerID            0952-KMEEH               7508-DQAKK
# gender                      Male                   Female
# SeniorCitizen                  0                        0
# Partner                       No                       No
# Dependents                    No                       No
# tenure                        13                       64
# PhoneService                 Yes                      Yes
# MultipleLines                Yes                      Yes
# InternetService      Fiber optic                      DSL
# OnlineSecurity               Yes                      Yes
# OnlineBackup                  No                      Yes
# DeviceProtection              No                      Yes
# TechSupport                   No                      Yes
# StreamingTV                  Yes                      Yes
# StreamingMovies              Yes                      Yes
# Contract          Month-to-month                 Two year
# PaperlessBilling              No                      Yes
# PaymentMethod       Mailed check  Credit card (automatic)
# MonthlyCharges             98.15                     86.4
# TotalCharges             1230.25                  5442.05
# Churn                        Yes                       No
#
#                                        6952                       481   \
# customerID                       6394-MFYNG                 0447-BEMNG
# gender                               Female                     Female
# SeniorCitizen                             0                          0
# Partner                                  No                        Yes
# Dependents                               No                         No
# tenure                                   48                         48
# PhoneService                            Yes                         No
# MultipleLines                           Yes           No phone service
# InternetService                 Fiber optic                        DSL
# OnlineSecurity                           No                        Yes
# OnlineBackup                            Yes                         No
# DeviceProtection                        Yes                        Yes
# TechSupport                              No                         No
# StreamingTV                             Yes                         No
# StreamingMovies                         Yes                        Yes
# Contract                     Month-to-month             Month-to-month
# PaperlessBilling                        Yes                        Yes
# PaymentMethod     Bank transfer (automatic)  Bank transfer (automatic)
# MonthlyCharges                        107.4                       45.3
# TotalCharges                         5121.3                     2145.0
# Churn                                   Yes                        Yes
#
#                                      6776                     5551  \
# customerID                     6120-RJKLU               8457-XIGKN
# gender                             Female                     Male
# SeniorCitizen                           1                        0
# Partner                               Yes                       No
# Dependents                             No                       No
# tenure                                 62                       20
# PhoneService                          Yes                      Yes
# MultipleLines                          No                       No
# InternetService                       DSL                       No
# OnlineSecurity                        Yes      No internet service
# OnlineBackup                           No      No internet service
# DeviceProtection                      Yes      No internet service
# TechSupport                           Yes      No internet service
# StreamingTV                           Yes      No internet service
# StreamingMovies                       Yes      No internet service
# Contract                         Two year           Month-to-month
# PaperlessBilling                      Yes                      Yes
# PaymentMethod     Credit card (automatic)  Credit card (automatic)
# MonthlyCharges                      79.95                     19.6
# TotalCharges                      4819.75                   356.15
# Churn                                  No                       No
#
#                               999               4146
# customerID              3234-VKACU        9821-POOTN
# gender                        Male              Male
# SeniorCitizen                    0                 0
# Partner                         No               Yes
# Dependents                      No                No
# tenure                           2                35
# PhoneService                   Yes               Yes
# MultipleLines                   No               Yes
# InternetService                DSL       Fiber optic
# OnlineSecurity                  No                No
# OnlineBackup                    No                No
# DeviceProtection                No                No
# TechSupport                    Yes                No
# StreamingTV                    Yes                No
# StreamingMovies                Yes                No
# Contract            Month-to-month    Month-to-month
# PaperlessBilling                No               Yes
# PaymentMethod     Electronic check  Electronic check
# MonthlyCharges                70.3              75.2
# TotalCharges                 132.4            2576.2
# Churn                           No               Yes

# %%
print(f"shape: {df.shape}")
print()
print(f"shape: {df.columns.to_list()}")
# Out:
# shape: (7043, 21)
#
# shape: ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
total_sum = df['TotalCharges'].sum()
print(total_sum)
# Out:
# 16056168.7

# %%
print(df.isnull().sum())
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
tenureArray = df['tenure'].to_numpy()

# %%
print(f"Max: {tenureArray.max()}\nMin: {tenureArray.min()}\nMean: {tenureArray.mean()}")
# Out:
# Max: 72
# Min: 0
# Mean: 32.37114865824223

# %%
print(f"Average: {df['MonthlyCharges'].mean()}")
# Out:
# Average: 64.76169246059918

# %%
print(f"Sum of MonthlyCharges: {df['MonthlyCharges'].sum()}")
# Out:
# Sum of MonthlyCharges: 456116.6

# %%
df1 = df.drop(columns=['customerID'])

# %%
print(f"Mean of tenure: {df1['tenure'].mean()}")
# Out:
# Mean of tenure: 32.37114865824223

# %%
print(f"Number of items: {df1['InternetService'].count()}")
# Out:
# Number of items: 7043

# %%
df.loc[0:10, 'TotalCharges']
# Out:
# 0       29.85
# 1     1889.50
# 2      108.15
# 3     1840.75
# 4      151.65
# 5      820.50
# 6     1949.40
# 7      301.90
# 8     3046.05
# 9     3487.95
# 10     587.45
# Name: TotalCharges, dtype: float64
